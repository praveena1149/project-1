# %% [markdown]
# <a href="https://colab.research.google.com/github/praveena1149/project-1/blob/main/earthquake.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests
import pandas as pd
import numpy as np
from datetime import datetime


url = "https://earthquake.usgs.gov/fdsnws/event/1/query"

all_records = []
start_year = datetime.now().year - 5   # last 5 years
end_year = datetime.now().year

for year in range(start_year, end_year + 1):
    for month in range(1, 13):
        start_date = f"{year}-{month:02d}-01"
        if month == 12:
            end_date = f"{year+1}-01-01"
        else:
            end_date = f"{year}-{month+1:02d}-01"

        params = {
            "format": "geojson",
            "starttime": start_date,
            "endtime": end_date,
            "minmagnitude": 3
        }

        response = requests.get(url, params=params)
        if response.status_code != 200:
            print(f"⚠️ Failed for {start_date}: {response.text[:200]}")
            continue

        try:
            data = response.json()
        except Exception as e:
            print(f"⚠️ JSON error for {start_date}: {e}")
            continue

        for f in data["features"]:
            p = f["properties"]
            g = f["geometry"]["coordinates"]
            all_records.append({
                "id": f.get("id"),
                "time": pd.to_datetime(p.get("time"), unit="ms"),
                "updated": pd.to_datetime(p.get("updated"), unit="ms"),
                "latitude": g[1] if g else None,
                "longitude": g[0] if g else None,
                "depth_km": g[2] if g else None,
                "mag":p.get("mag"),
                "magType":p.get("magType"),
                'alert':p.get('alert'),
                'felt':p.get('felt'),
                'cdi':p.get('cdi'),
                 'mmi':p.get('mmi'),
                 "code":p.get("code"),


                "place":p.get("place"),
                "status":p.get("status"),
                "tsunami":p.get("tsunami"),
                " sig":p.get("sig"),
                "net":p.get("net"),
                "nst":p.get("nst"),
                "dmin":p.get("dmin"),
                "rms":p.get("rms"),
                "gap":p.get("gap"),
                "types":p.get("types"),
                "ids":p.get("ids"),
                "sources":p.get("sources"),
                "type":p.get("type"),








              # Event type
           })

df = pd.DataFrame(all_records)
df["alert"]=df["alert"].fillna(("green"))
df["felt"]=df["felt"].fillna(df["felt"].mean())
df["cdi"]=df["cdi"].fillna(df["cdi"].mean())
df["mmi"]=df["mmi"].fillna(df["mmi"].mean())
df["nst"]=df["nst"].fillna(df["nst"].mean())
df["dmin"]=df["rms"].fillna(df["rms"].mean())
df["rms"]=df["rms"].fillna(df["rms"].mean())
df["gap"]=df["gap"].fillna(df["gap"].mean())
df
# Out:
#                   id                    time                 updated  \
# 0         us6000ddi8 2021-01-31 23:20:49.923 2021-04-16 19:02:44.040
# 1         us6000dev6 2021-01-31 23:08:17.161 2021-04-16 19:03:47.040
# 2         us6000dev5 2021-01-31 22:54:19.760 2021-04-16 19:03:47.040
# 3         us6000ddhs 2021-01-31 22:06:00.832 2021-04-16 19:02:43.040
# 4         us6000dev4 2021-01-31 21:51:14.016 2021-04-16 19:03:46.040
# ...              ...                     ...                     ...
# 106045    us6000s5u8 2026-02-01 09:12:02.566 2026-02-01 13:45:33.040
# 106046    us6000s5ur 2026-02-01 06:44:49.812 2026-02-04 06:28:18.040
# 106047    us6000s5tq 2026-02-01 05:11:19.683 2026-02-04 00:11:13.784
# 106048    us6000s5t1 2026-02-01 01:22:46.845 2026-02-02 14:00:49.983
# 106049  ak2026ceykff 2026-02-01 00:29:10.296 2026-02-05 21:01:29.818
#
#         latitude  longitude  depth_km  mag magType  alert        felt  ...  \
# 0       -31.7493   -68.9337    17.270  4.7     mwr  green   12.000000  ...
# 1       -15.4902  -177.2052   426.710  4.1      mb  green   98.690541  ...
# 2        19.7529   121.3159    46.730  4.7      mb  green   98.690541  ...
# 3        28.1524    57.2570    10.000  4.9      mb  green   98.690541  ...
# 4        71.3212    -3.7578    10.000  4.0      mb  green   98.690541  ...
# ...          ...        ...       ...  ...     ...    ...         ...  ...
# 106045  -22.2362  -178.0947   376.934  4.4      mb  green   98.690541  ...
# 106046   -4.7960  -105.8692    10.000  5.0     mww  green   98.690541  ...
# 106047   27.4337    52.6436    10.000  5.2     mww  green    4.000000  ...
# 106048   47.5295  -111.2143     9.723  3.2      ml  green  197.000000  ...
# 106049   60.2920  -152.8630   115.900  3.1      ml  green   98.690541  ...
#
#          sig  net         nst  dmin   rms    gap  \
# 0        344   us   45.344097  0.82  0.82   42.0
# 1        259   us   45.344097  0.29  0.29   64.0
# 2        340   us   45.344097  0.69  0.69  106.0
# 3        369   us   45.344097  0.61  0.61   71.0
# 4        246   us   45.344097  0.50  0.50   65.0
# ...      ...  ...         ...   ...   ...    ...
# 106045   298   us   34.000000  1.00  1.00  121.0
# 106046   385   us   90.000000  0.64  0.64  158.0
# 106047   418   us   65.000000  0.71  0.71   47.0
# 106048   217   us   38.000000  0.90  0.90   95.0
# 106049   148   ak  106.000000  0.90  0.90   46.0
#
#                                                     types  \
# 0                  ,dyfi,moment-tensor,origin,phase-data,
# 1                                     ,origin,phase-data,
# 2                                     ,origin,phase-data,
# 3                                     ,origin,phase-data,
# 4                                     ,origin,phase-data,
# ...                                                   ...
# 106045                                ,origin,phase-data,
# 106046                                ,origin,phase-data,
# 106047  ,dyfi,internal-moment-tensor,moment-tensor,ori...
# 106048                           ,dyfi,origin,phase-data,
# 106049                                ,origin,phase-data,
#
#                                 ids      sources        type
# 0                      ,us6000ddi8,         ,us,  earthquake
# 1                      ,us6000dev6,         ,us,  earthquake
# 2                      ,us6000dev5,         ,us,  earthquake
# 3                      ,us6000ddhs,         ,us,  earthquake
# 4                      ,us6000dev4,         ,us,  earthquake
# ...                             ...          ...         ...
# 106045                 ,us6000s5u8,         ,us,  earthquake
# 106046                 ,us6000s5ur,         ,us,  earthquake
# 106047  ,us6000s5tq,usauto6000s5tq,  ,us,usauto,  earthquake
# 106048                 ,us6000s5t1,         ,us,  earthquake
# 106049    ,us6000s5sz,ak2026ceykff,      ,us,ak,  earthquake
#
# [106050 rows x 26 columns]

# %%
df["alert"].unique()
# Out:
# array(['green', nan, 'yellow', 'orange', 'red'], dtype=object)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 106044 entries, 0 to 106043
# Data columns (total 26 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   id         106044 non-null  object
#  1   time       106044 non-null  datetime64[ns]
#  2   updated    106044 non-null  datetime64[ns]
#  3   latitude   106044 non-null  float64
#  4   longitude  106044 non-null  float64
#  5   depth_km   106044 non-null  float64
#  6   mag        106044 non-null  float64
#  7   magType    106044 non-null  object
#  8   alert      4348 non-null    object
#  9   felt       106044 non-null  float64
#  10  cdi        106044 non-null  float64
#  11  mmi        106044 non-null  float64
#  12  code       106044 non-null  object
#  13  place      106044 non-null  object
#  14  status     106044 non-null  object
#  15  tsunami    106044 non-null  int64
#  16   sig       106044 non-null  int64
#  17  net        106044 non-null  object
#  18  nst        106044 non-null  float64
#  19  dmin       106044 non-null  float64
#  20  rms        106044 non-null  float64
#  21  gap        106044 non-null  float64
#  22  types      106044 non-null  object
#  23  ids        106044 non-null  object
#  24  sources    106044 non-null  object
#  25  type       106044 non-null  object
# dtypes: datetime64[ns](2), float64(11), int64(2), object(11)
# memory usage: 21.0+ MB

# %%
df["alert"]=df["alert"].fillna("green")
df["felt"]=df["felt"].fillna(df["felt"].mean())
df["cdi"]=df["cdi"].fillna(df["cdi"].mean())
df["mmi"]=df["mmi"].fillna(df["mmi"].mean())
df["nst"]=df["nst"].fillna(df["nst"].mean())
df["dmin"]=df["rms"].fillna(df["rms"].mean())
df["rms"]=df["rms"].fillna(df["rms"].mean())
df["gap"]=df["gap"].fillna(df["gap"].mean())
df
# Out:
#                   id                    time                 updated  \
# 0         us6000ddi8 2021-01-31 23:20:49.923 2021-04-16 19:02:44.040
# 1         us6000dev6 2021-01-31 23:08:17.161 2021-04-16 19:03:47.040
# 2         us6000dev5 2021-01-31 22:54:19.760 2021-04-16 19:03:47.040
# 3         us6000ddhs 2021-01-31 22:06:00.832 2021-04-16 19:02:43.040
# 4         us6000dev4 2021-01-31 21:51:14.016 2021-04-16 19:03:46.040
# ...              ...                     ...                     ...
# 106041    us6000s5u8 2026-02-01 09:12:02.566 2026-02-01 13:45:33.040
# 106042    us6000s5ur 2026-02-01 06:44:49.812 2026-02-04 06:28:18.040
# 106043    us6000s5tq 2026-02-01 05:11:19.683 2026-02-04 00:11:13.784
# 106044    us6000s5t1 2026-02-01 01:22:46.845 2026-02-02 14:00:49.983
# 106045  ak2026ceykff 2026-02-01 00:29:10.296 2026-02-05 21:01:29.818
#
#         latitude  longitude  depth_km  mag magType    alert        felt  ...  \
# 0       -31.7493   -68.9337    17.270  4.7     mwr  unknown   12.000000  ...
# 1       -15.4902  -177.2052   426.710  4.1      mb  unknown   98.696097  ...
# 2        19.7529   121.3159    46.730  4.7      mb  unknown   98.696097  ...
# 3        28.1524    57.2570    10.000  4.9      mb  unknown   98.696097  ...
# 4        71.3212    -3.7578    10.000  4.0      mb  unknown   98.696097  ...
# ...          ...        ...       ...  ...     ...      ...         ...  ...
# 106041  -22.2362  -178.0947   376.934  4.4      mb  unknown   98.696097  ...
# 106042   -4.7960  -105.8692    10.000  5.0     mww  unknown   98.696097  ...
# 106043   27.4337    52.6436    10.000  5.2     mww  unknown    4.000000  ...
# 106044   47.5295  -111.2143     9.723  3.2      ml  unknown  197.000000  ...
# 106045   60.2920  -152.8630   115.900  3.1      ml  unknown   98.696097  ...
#
#          sig  net         nst  dmin   rms    gap  \
# 0        344   us   45.343795  0.82  0.82   42.0
# 1        259   us   45.343795  0.29  0.29   64.0
# 2        340   us   45.343795  0.69  0.69  106.0
# 3        369   us   45.343795  0.61  0.61   71.0
# 4        246   us   45.343795  0.50  0.50   65.0
# ...      ...  ...         ...   ...   ...    ...
# 106041   298   us   34.000000  1.00  1.00  121.0
# 106042   385   us   90.000000  0.64  0.64  158.0
# 106043   418   us   65.000000  0.71  0.71   47.0
# 106044   217   us   38.000000  0.90  0.90   95.0
# 106045   148   ak  106.000000  0.90  0.90   46.0
#
#                                                     types  \
# 0                  ,dyfi,moment-tensor,origin,phase-data,
# 1                                     ,origin,phase-data,
# 2                                     ,origin,phase-data,
# 3                                     ,origin,phase-data,
# 4                                     ,origin,phase-data,
# ...                                                   ...
# 106041                                ,origin,phase-data,
# 106042                                ,origin,phase-data,
# 106043  ,dyfi,internal-moment-tensor,moment-tensor,ori...
# 106044                           ,dyfi,origin,phase-data,
# 106045                                ,origin,phase-data,
#
#                                 ids      sources        type
# 0                      ,us6000ddi8,         ,us,  earthquake
# 1                      ,us6000dev6,         ,us,  earthquake
# 2                      ,us6000dev5,         ,us,  earthquake
# 3                      ,us6000ddhs,         ,us,  earthquake
# 4                      ,us6000dev4,         ,us,  earthquake
# ...                             ...          ...         ...
# 106041                 ,us6000s5u8,         ,us,  earthquake
# 106042                 ,us6000s5ur,         ,us,  earthquake
# 106043  ,us6000s5tq,usauto6000s5tq,  ,us,usauto,  earthquake
# 106044                 ,us6000s5t1,         ,us,  earthquake
# 106045    ,us6000s5sz,ak2026ceykff,      ,us,ak,  earthquake
#
# [106046 rows x 26 columns]

# %%
df.isnull().sum()
# Out:
# id           0
# time         0
# updated      0
# latitude     0
# longitude    0
# depth_km     0
# mag          0
# magType      0
# alert        0
# felt         0
# cdi          0
# mmi          0
# code         0
# place        0
# status       0
# tsunami      0
#  sig         0
# net          0
# nst          0
# dmin         0
# rms          0
# gap          0
# types        0
# ids          0
# sources      0
# type         0
# dtype: int64
